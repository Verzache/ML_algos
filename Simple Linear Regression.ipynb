# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = iris[['petal_length','petal_width']]

# %%
X = iris['petal_length']
y = iris['petal_width']

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)
plt.xlabel('petal length')
plt.ylabel('peta; width')
# Out:
# Text(0, 0.5, 'peta; width')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 42)

# %%
import numpy as np
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
Y_pred_train = lr.predict(X_train)
Y_pred_train
# Out:
# array([0.21810811, 0.25949235, 1.74932472, 1.50101933, 1.58378779,
#        0.17672388, 0.25949235, 1.16994546, 1.74932472, 1.91486165,
#        1.45963509, 2.16316705, 1.37686663, 2.37008821, 1.50101933,
#        0.21810811, 2.41147245, 1.3354824 , 0.21810811, 0.17672388,
#        0.42502928, 1.087177  , 1.66655626, 0.42502928, 0.30087658,
#        0.34226081, 1.37686663, 0.25949235, 1.37686663, 2.41147245,
#        0.21810811, 1.41825086, 1.70794049, 0.21810811, 1.62517202,
#        1.74932472, 1.29409816, 1.50101933, 1.87347742, 1.29409816,
#        0.34226081, 1.00440853, 1.83209319, 0.21810811, 0.13533965,
#        1.2113297 , 1.70794049, 0.25949235, 1.74932472, 0.25949235,
#        0.30087658, 1.62517202, 0.88025584, 1.99763012, 1.74932472,
#        1.95624589, 2.16316705, 1.29409816, 0.21810811, 0.09395541,
#        1.70794049, 2.12178282, 0.25949235, 0.21810811, 0.17672388,
#        1.66655626, 1.95624589, 0.21810811, 1.91486165, 2.12178282,
#        0.17672388, 1.58378779, 1.54240356, 1.62517202, 1.58378779,
#        1.83209319, 0.30087658, 1.87347742, 1.37686663, 1.79070896,
#        1.087177  , 1.25271393, 1.54240356, 0.17672388, 1.54240356,
#        1.45963509, 0.25949235, 1.3354824 , 2.24593552, 1.99763012,
#        0.25949235, 1.00440853, 1.99763012, 2.03901435, 0.21810811,
#        1.95624589, 0.21810811, 1.66655626, 2.16316705, 1.95624589,
#        1.3354824 , 1.91486165, 1.45963509, 1.41825086, 1.66655626,
#        1.74932472, 0.34226081, 1.29409816, 1.50101933, 0.13533965,
#        1.29409816, 2.08039858])

# %%
Y_pred_test = lr.predict(X_test)
Y_pred_test
# Out:
# array([1.58378779, 0.34226081, 2.49424091, 1.50101933, 1.62517202,
#        0.25949235, 1.12856123, 1.74932472, 1.50101933, 1.25271393,
#        1.74932472, 0.21810811, 0.17672388, 0.25949235, 0.25949235,
#        1.58378779, 2.03901435, 1.25271393, 1.50101933, 1.95624589,
#        0.30087658, 1.66655626, 0.30087658, 1.95624589, 2.28731975,
#        1.79070896, 2.03901435, 2.08039858, 0.21810811, 0.30087658,
#        0.05257118, 0.25949235, 1.45963509, 0.30087658, 0.17672388,
#        1.70794049, 1.50101933, 0.25949235])

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train)
plt.plot(X_train, Y_pred_train, color='red')
plt.xlabel('sepal length')
plt.ylabel('sepa; width')
# Out:
# Text(0, 0.5, 'sepa; width')

# %%
Y_pred_test = lr.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(X_test,y_test)
plt.plot(X_test, Y_pred_test, color='red')
plt.xlabel('sepal length')
plt.ylabel('sepa; width')
# Out:
# Text(0, 0.5, 'sepa; width')

# %%
from sklearn.metrics import r2_score
num1 = r2_score(y_test,Y_pred_test)
num1
# Out:
# 0.9398857910361995

# %%
from sklearn.metrics import mean_squared_error
num2 = mean_squared_error(y_test,Y_pred_test)
num2
# Out:
# np.float64(0.03855843593099837)
